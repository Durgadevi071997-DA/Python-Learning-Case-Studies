# %% [markdown]
# **Case Study – Shopping Cart System**

# %% [markdown]
# Create a list named cart with initial items: Milk, Bread, Eggs, Apple

# %%
cart = ["Milk", "Bread", "Eggs", "Apple"]
print("Initial Cart:", cart)
# Out:
# Initial Cart: ['Milk', 'Bread', 'Eggs', 'Apple']

# %% [markdown]
# • Add multiple items using extend()

# %%
cart.extend(["Banana", "Butter"])
print(cart)
# Out:
# ['Milk', 'Bread', 'Eggs', 'Apple', 'Banana', 'Butter']

# %% [markdown]
#  Remove item Apple using remove()

# %%
cart.remove("Apple")
print(cart)
# Out:
# ['Milk', 'Bread', 'Eggs', 'Banana', 'Butter']

# %% [markdown]
#  Insert item at index 2 using insert()

# %%
cart.insert(2, "Cheese")
print(cart)
# Out:
# ['Milk', 'Bread', 'Cheese', 'Eggs', 'Banana', 'Butter']

# %% [markdown]
# • Remove last item using pop()

# %%
cart.pop()
print(cart)
# Out:
# ['Milk', 'Bread', 'Cheese', 'Eggs', 'Banana']

# %% [markdown]
# • index() to find position of Eggs

# %%
print("position of eggs:",cart.index("Eggs"))
# Out:
# position of eggs: 3

# %% [markdown]
# • count() to count occurrences of Milk

# %%
print("Count of Milk:", cart.count("Milk"))
# Out:
# Count of Milk: 1

# %% [markdown]
# • Display first item

# %%
print("First item:", cart[0])
# Out:
# First item: Milk

# %% [markdown]
# • Display last item

# %%
print("Last item:", cart[-1])
# Out:
# Last item: Banana

# %% [markdown]
# • Display first 3 items from the list

# %%
print("First 3 items:", cart[:3])
# Out:
# First 3 items: ['Milk', 'Bread', 'Cheese']

# %% [markdown]
# Find total number of items using len()

# %%
print("Total of item:", len(cart))
# Out:
# Total of item: 5

# %% [markdown]
# Display all outputs using print()

# %%
print("Shopping Cart:", cart)

print("Position of Eggs:", cart.index("Eggs"))

print("Count of Milk:", cart.count("Milk"))

print("First Item:", cart[0])

print("Last Item:", cart[-1])

print("First 3 Items:", cart[:3])

print("Total Number of Items:", len(cart))
# Out:
# Shopping Cart: ['Milk', 'Bread', 'Cheese', 'Eggs', 'Banana']
# Position of Eggs: 3
# Count of Milk: 1
# First Item: Milk
# Last Item: Banana
# First 3 Items: ['Milk', 'Bread', 'Cheese']
# Total Number of Items: 5

# %%
# 1. Largest of Three Numbers
def largest(a, b, c):
    return max(a, b, c)

print("Largest Number:", largest(10, 25, 15))


# 2. Factorial Using Recursion
def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)

print("Factorial:", factorial(5))


# 3. Check Palindrome
def is_palindrome(text):
    return text == text[::-1]

print("Palindrome:", is_palindrome("madam"))


# 4. Sum of All Elements in a List
def sum_list(numbers):
    return sum(numbers)

print("Sum:", sum_list([10, 20, 30, 40]))


# 5. Average Using *args
def average(*args):
    return sum(args) / len(args)

print("Average:", average(10, 20, 30, 40, 50))


# 6. Count Students Scoring Above 75
def count_above_75(marks):
    count = 0
    for mark in marks:
        if mark > 75:
            count += 1
    return count

print("Students Above 75:", count_above_75([80, 60, 90, 70, 85]))


# 7. Total Sales Greater Than Threshold
def total_sales_above_threshold(sales, threshold):
    total = 0
    for sale in sales:
        if sale > threshold:
            total += sale
    return total

print("Total Sales:", total_sales_above_threshold([1000, 5000, 3000, 7000], 3000))


# 8. Count Vowels in a String
def count_vowels(text):
    vowels = "aeiouAEIOU"
    count = 0
    for char in text:
        if char in vowels:
            count += 1
    return count

print("Vowels:", count_vowels("Python Programming"))


# 9. Return Even Numbers from a List
def even_numbers(numbers):
    evens = []
    for num in numbers:
        if num % 2 == 0:
            evens.append(num)
    return evens

print("Even Numbers:", even_numbers([1, 2, 3, 4, 5, 6, 7, 8]))


# 10. Monthly Bonus for Employees
def calculate_bonus(employee_sales):
    bonuses = []

    for sales in employee_sales:
        if sales > 50000:
            bonus = sales * 0.10
        elif 30000 <= sales <= 50000:
            bonus = sales * 0.05
        else:
            bonus = 0

        bonuses.append(bonus)

    return bonuses

sales_list = [25000, 35000, 60000, 45000, 80000]
print("Employee Bonuses:", calculate_bonus(sales_list))
# Out:
# Largest Number: 25
# Factorial: 120
# Palindrome: True
# Sum: 100
# Average: 30.0
# Students Above 75: 3
# Total Sales: 12000
# Vowels: 4
# Even Numbers: [2, 4, 6, 8]
# Employee Bonuses: [0, 1750.0, 6000.0, 2250.0, 8000.0]

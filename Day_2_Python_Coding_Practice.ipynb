# %% [markdown]
# **Day2 Python Coding Practice**

# %% [markdown]
# 1.Read two numbers and perform all arithmetic operations

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Enter first number: 1
# Enter second number: 5
# Addition: 6
# Subtraction: -4
# Multiplication: 5
# Division: 0.2

# %% [markdown]
# 2.Check the data type of the value entered

# %%
print(type (a))
print(type (b))
# Out:
# <class 'int'>
# <class 'int'>

# %% [markdown]
# 3.Find the length of a string and count the number of words

# %%
text = "i am a makeup artist"
print(len(text))
# Out:
# 20

# %%
print(text.count('a'))
# Out:
# 4

# %% [markdown]
# 4.Count words in a sentence

# %%
print(text.count('am'))
# Out:
# 1

# %% [markdown]
# 5.Reverse each word in a sentence

# %%
print(text[::-1])
# Out:
# tsitra puekam a ma i

# %% [markdown]
# 6.Check whether a character is a vowel or consonant

# %%
text = "i am a makeup artist"

if ch in ['a', 'e', 'i', 'o', 'u']:
    print(text, "vowel")
else:
    print(text, "consonant")
# Out:
# i am a makeup artist vowel

# %% [markdown]
# 7.Check if a string is a palindrome

# %%
text = "mom"

reverse_text = text[::-1]

if text == reverse_text:
    print(text, "palindrome")
else:
    print(text, "not palindrome")
# Out:
# mom palindrome
